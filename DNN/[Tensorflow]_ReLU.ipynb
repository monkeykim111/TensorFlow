# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from time import time
import os
print(tf.__version__)
# Out:
# 2.5.0

# %% [markdown]
# checkpoint function

# %%
def load(model, checkpoint_dir):
    print(" [*] Reading checkpoints...")

    ckpt = tf.train.get_checkpoint_state(checkpoint_dir)
    if ckpt :
        ckpt_name = os.path.basename(ckpt.model_checkpoint_path)
        checkpoint = tf.train.Checkpoint(dnn=model)
        checkpoint.restore(save_path=os.path.join(checkpoint_dir, ckpt_name))
        counter = int(ckpt_name.split('-')[1])
        print(" [*] Success to read {}".format(ckpt_name))
        return True, counter
    else:
        print(" [*] Failed to find a checkpoint")
        return False, 0

def check_folder(dir):
    if not os.path.exists(dir):
        os.makedirs(dir)
    return dir

# %% [markdown]
# data load & preprocessing function

# %%
def load_mnist():
  (train_data, train_labels), (test_data, test_labels) = mnist.load_data()
  train_data = np.expand_dims(train_data, axis=-1) # [N, 28, 28] -> [N, 28, 28, 1]
  test_data = np.expand_dims(test_data, axis=-1) # [N, 28, 28] -> [N, 28, 28, 1]

  train_data, test_data = normalize(train_data, test_data)

  train_labels = to_categorical(train_labels, 10) # [N,] -> [N, 10]
  test_labels = to_categorical(test_labels, 10) # [N,] -> [N, 10]

  return train_data, train_labels, test_data, test_labels

def normalize(train_data, test_data):
    train_data = train_data.astype(np.float32) / 255.0
    test_data = test_data.astype(np.float32) / 255.0

    return train_data, test_data

# %% [markdown]
# performance function

# %%
def loss_fn(model, images, labels):
    logits = model(images, training=True)    
    loss = tf.reduce_mean(tf.keras.losses.categorical_crossentropy(y_pred=logits, y_true=labels, 
                                                                   from_logits=True))
    return loss

def accuracy_fn(model, images, labels):
    logits = model(images, training=False)
    prediction = tf.equal(tf.argmax(logits, -1), tf.argmax(labels, -1))
    accuracy = tf.reduce_mean(tf.cast(prediction, tf.float32))
    return accuracy

def grad(model, images, labels):
    with tf.GradientTape() as tape:
        loss = loss_fn(model, images, labels)
    return tape.gradient(loss, model.variables)

# %% [markdown]
# model function

# %%
def flatten() :
    return tf.keras.layers.Flatten()

def dense(label_dim, weight_init) :
    return tf.keras.layers.Dense(units=label_dim, use_bias=True, kernel_initializer=weight_init)

def sigmoid() :
    return tf.keras.layers.Activation(tf.keras.activations.sigmoid)

# %% [markdown]
# create model

# %%
class create_model_class(tf.keras.Model):
    def __init__(self, label_dim):
        super(create_model_class, self).__init__()
        weight_init = tf.keras.initializers.RandomNormal()

        self.model = tf.keras.Sequential()
        self.model.add(flatten())

        for i in range(2):
            self.model.add(dense(256, weight_init))
            self.model.add(sigmoid())

        self.model.add(dense(label_dim, weight_init))

    def call(self, x, training=None, mask=None):
        x = self.model(x)

        return x

# %%
def create_model_function(label_dim) :
    weight_init = tf.keras.initializers.RandomNormal()

    model = tf.keras.Sequential()
    model.add(flatten())

    for i in range(2) :
        model.add(dense(256, weight_init))
        model.add(sigmoid())

    model.add(dense(label_dim, weight_init))

    return model

# %% [markdown]
# define data & hyper-parameter

# %%
""" dataset """
train_x, train_y, test_x, test_y = load_mnist()

""" parameters """
learning_rate = 0.001
batch_size = 128

training_epochs = 1
training_iterations = len(train_x) // batch_size

label_dim = 10

train_flag = True

""" Graph Input using Dataset API """
train_dataset = tf.data.Dataset.from_tensor_slices((train_x, train_y)).\
    shuffle(buffer_size=100000).\
    prefetch(buffer_size=batch_size).\
    batch(batch_size, drop_remainder=True)

test_dataset = tf.data.Dataset.from_tensor_slices((test_x, test_y)).\
    shuffle(buffer_size=100000).\
    prefetch(buffer_size=len(test_x)).\
    batch(len(test_x))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# define model & optimizer & writer

# %%
""" Model """
network = create_model_function(label_dim)

""" Training """
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

""" Writer """
checkpoint_dir = 'checkpoints'
logs_dir = 'logs'

model_dir = 'nn_softmax'

checkpoint_dir = os.path.join(checkpoint_dir, model_dir)
check_folder(checkpoint_dir)
checkpoint_prefix = os.path.join(checkpoint_dir, model_dir)
logs_dir = os.path.join(logs_dir, model_dir)

# %% [markdown]
# restore checkpoint & start train or test phase

# %%
if train_flag :

    checkpoint = tf.train.Checkpoint(dnn=network)

    # create writer for tensorboard
    summary_writer = tf.summary.create_file_writer(logdir=logs_dir)
    start_time = time()

    # restore check-point if it exits
    could_load, checkpoint_counter = load(network, checkpoint_dir)    

    if could_load:
        start_epoch = (int)(checkpoint_counter / training_iterations)        
        counter = checkpoint_counter        
        print(" [*] Load SUCCESS")
    else:
        start_epoch = 0
        start_iteration = 0
        counter = 0
        print(" [!] Load failed...")
    
    # train phase
    with summary_writer.as_default():  # for tensorboard
        for epoch in range(start_epoch, training_epochs):
            for idx, (train_input, train_label) in enumerate(train_dataset):            
                grads = grad(network, train_input, train_label)
                optimizer.apply_gradients(grads_and_vars=zip(grads, network.variables))

                train_loss = loss_fn(network, train_input, train_label)
                train_accuracy = accuracy_fn(network, train_input, train_label)
                
                for test_input, test_label in test_dataset:                
                    test_accuracy = accuracy_fn(network, test_input, test_label)

                tf.summary.scalar(name='train_loss', data=train_loss, step=counter)
                tf.summary.scalar(name='train_accuracy', data=train_accuracy, step=counter)
                tf.summary.scalar(name='test_accuracy', data=test_accuracy, step=counter)

                print(
                    "Epoch: [%2d] [%5d/%5d] time: %4.4f, train_loss: %.8f, train_accuracy: %.4f, test_Accuracy: %.4f" \
                    % (epoch, idx, training_iterations, time() - start_time, train_loss, train_accuracy,
                       test_accuracy))
                counter += 1                
        checkpoint.save(file_prefix=checkpoint_prefix + '-{}'.format(counter))
        
# test phase      
else :
    _, _ = load(network, checkpoint_dir)
    for test_input, test_label in test_dataset:    
        test_accuracy = accuracy_fn(network, test_input, test_label)

    print("test_Accuracy: %.4f" % (test_accuracy))
# Out:
#  [*] Reading checkpoints...
#  [*] Failed to find a checkpoint
#  [!] Load failed...
# Epoch: [ 0] [    0/  468] time: 1.1752, train_loss: 2.28769255, train_accuracy: 0.1328, test_Accuracy: 0.0974
# Epoch: [ 0] [    1/  468] time: 1.5284, train_loss: 2.29067612, train_accuracy: 0.1328, test_Accuracy: 0.1680
# Epoch: [ 0] [    2/  468] time: 1.7415, train_loss: 2.25354195, train_accuracy: 0.1953, test_Accuracy: 0.1268
# Epoch: [ 0] [    3/  468] time: 2.0990, train_loss: 2.26474595, train_accuracy: 0.1250, test_Accuracy: 0.0958
# Epoch: [ 0] [    4/  468] time: 2.4494, train_loss: 2.26032043, train_accuracy: 0.0938, test_Accuracy: 0.1185
# Epoch: [ 0] [  375/  468] time: 94.2979, train_loss: 0.25450784, train_accuracy: 0.9141, test_Accuracy: 0.9173
# Epoch: [ 0] [  376/  468] time: 94.6602, train_loss: 0.27168420, train_accuracy: 0.9297, test_Accuracy: 0.9168
# Epoch: [ 0] [  377/  468] time: 94.8606, train_loss: 0.32287872, train_accuracy: 0.9219, test_Accuracy: 0.9164
# Epoch: [ 0] [  378/  468] time: 95.0715, train_loss: 0.32259816, train_accuracy: 0.8906, test_Accuracy: 0.9171
# Epoch: [ 0] [  379/  468] time: 95.4283, train_loss: 0.26418906, train_accuracy: 0.9375, test_Accuracy: 0.9173
# Epoch: [ 0] [  380/  468] time: 95.6289, train_loss: 0.24514401, train_accuracy: 0.9219, test_Accuracy: 0.9177
# Epoch: [ 0] [  381/  468] time: 95.8387, train_loss: 0.36391726, train_accuracy: 0.8672, test_Accuracy: 0.9172
# Epoch: [ 0] [  382/  468] time: 96.0414, train_loss: 0.23665428, train_accuracy: 0.9453, test_Accuracy: 0.9181
# Epoch: [ 0] [  383/  468] time: 96.2417, train_loss: 0.26956478, train_accuracy: 0.9219, test_Accuracy: 0.9176
# Epoch: [ 0] [  384/  468] time: 96.5954, train_loss: 0.33459878, train_accuracy: 0.8828, test_Accuracy: 0.9174
# Epoch: [ 0] [  385/  468] time: 96.8067, train_loss: 0.16915169, train_accuracy: 0.9531, test_Accuracy: 0.9181
# Epoch: [ 0] [  386/  468] time: 97.0040, train_loss: 0.29797018, train_accuracy: 0.9062, test_Accuracy: 0.9191
# Epoch: [ 0] [  387/  468] time: 97.2103, train_loss: 0.20531586, train_accuracy: 0.9531, test_Accuracy: 0.9192
# Epoch: [ 0] [  388/  468] time: 97.4100, train_loss: 0.24884430, train_accuracy: 0.9219, test_Accuracy: 0.9194
# Epoch: [ 0] [  389/  468] time: 97.6144, train_loss: 0.26804072, train_accuracy: 0.9062, test_Accuracy: 0.9196
# Epoch: [ 0] [  390/  468] time: 97.8195, train_loss: 0.25024414, train_accuracy: 0.9297, test_Accuracy: 0.9205
# Epoch: [ 0] [  391/  468] time: 98.0188, train_loss: 0.22490083, train_accuracy: 0.9297, test_Accuracy: 0.9209
# Epoch: [ 0] [  392/  468] time: 98.2342, train_loss: 0.29804647, train_accuracy: 0.8984, test_Accuracy: 0.9206
# Epoch: [ 0] [  393/  468] time: 98.5952, train_loss: 0.25710076, train_accuracy: 0.9219, test_Accuracy: 0.9214
# Epoch: [ 0] [  394/  468] time: 98.7929, train_loss: 0.48658434, train_accuracy: 0.8750, test_Accuracy: 0.9205
# Epoch: [ 0] [  395/  468] time: 99.0165, train_loss: 0.17287794, train_accuracy: 0.9297, test_Accuracy: 0.9210
# Epoch: [ 0] [  396/  468] time: 99.3808, train_loss: 0.24417195, train_accuracy: 0.9453, test_Accuracy: 0.9203
# Epoch: [ 0] [  397/  468] time: 99.5816, train_loss: 0.21813700, train_accuracy: 0.9453, test_Accuracy: 0.9205
# Epoch: [ 0] [  445/  468] time: 111.0419, train_loss: 0.20598370, train_accuracy: 0.9453, test_Accuracy: 0.9215
# Epoch: [ 0] [  446/  468] time: 111.3940, train_loss: 0.21458393, train_accuracy: 0.9453, test_Accuracy: 0.9226
# Epoch: [ 0] [  447/  468] time: 111.5943, train_loss: 0.25422981, train_accuracy: 0.9141, test_Accuracy: 0.9224
# Epoch: [ 0] [  448/  468] time: 111.8139, train_loss: 0.37394336, train_accuracy: 0.8906, test_Accuracy: 0.9224
# Epoch: [ 0] [  449/  468] time: 112.0297, train_loss: 0.33996069, train_accuracy: 0.8984, test_Accuracy: 0.9232
# Epoch: [ 0] [  450/  468] time: 112.2271, train_loss: 0.28082454, train_accuracy: 0.9219, test_Accuracy: 0.9248
# Epoch: [ 0] [  451/  468] time: 112.4407, train_loss: 0.32570919, train_accuracy: 0.8828, test_Accuracy: 0.9237
# Epoch: [ 0] [  452/  468] time: 112.7920, train_loss: 0.37222126, train_accuracy: 0.8750, test_Accuracy: 0.9229
# Epoch: [ 0] [  453/  468] time: 113.1534, train_loss: 0.29604515, train_accuracy: 0.9062, test_Accuracy: 0.9233
# Epoch: [ 0] [  454/  468] time: 113.5111, train_loss: 0.22951221, train_accuracy: 0.9531, test_Accuracy: 0.9235
# Epoch: [ 0] [  455/  468] time: 113.7165, train_loss: 0.36755055, train_accuracy: 0.8906, test_Accuracy: 0.9234
# Epoch: [ 0] [  456/  468] time: 114.0701, train_loss: 0.25588709, train_accuracy: 0.8906, test_Accuracy: 0.9230
# Epoch: [ 0] [  457/  468] time: 114.2879, train_loss: 0.24994531, train_accuracy: 0.9141, test_Accuracy: 0.9234
# Epoch: [ 0] [  458/  468] time: 114.5027, train_loss: 0.18319964, train_accuracy: 0.9453, test_Accuracy: 0.9234
# Epoch: [ 0] [  459/  468] time: 114.8600, train_loss: 0.29102454, train_accuracy: 0.9219, test_Accuracy: 0.9234
# Epoch: [ 0] [  460/  468] time: 115.0934, train_loss: 0.18807326, train_accuracy: 0.9453, test_Accuracy: 0.9252
# Epoch: [ 0] [  461/  468] time: 115.3071, train_loss: 0.25481582, train_accuracy: 0.9141, test_Accuracy: 0.9240
# Epoch: [ 0] [  462/  468] time: 115.5214, train_loss: 0.15854394, train_accuracy: 0.9609, test_Accuracy: 0.9248
# Epoch: [ 0] [  463/  468] time: 115.7216, train_loss: 0.25687537, train_accuracy: 0.9297, test_Accuracy: 0.9255
# Epoch: [ 0] [  464/  468] time: 115.9342, train_loss: 0.16095637, train_accuracy: 0.9766, test_Accuracy: 0.9257
# Epoch: [ 0] [  465/  468] time: 116.2841, train_loss: 0.24394184, train_accuracy: 0.9141, test_Accuracy: 0.9255
# Epoch: [ 0] [  466/  468] time: 116.5000, train_loss: 0.29933617, train_accuracy: 0.9219, test_Accuracy: 0.9247
# Epoch: [ 0] [  467/  468] time: 116.7141, train_loss: 0.19571209, train_accuracy: 0.9531, test_Accuracy: 0.9236
